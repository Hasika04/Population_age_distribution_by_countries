# %% [markdown]
# # Task 01 – Age Group Distribution by Country
#
# In this task, we visualize the population distribution by age groups across the top 10 most populous countries using a stacked bar chart.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/LENOVO/Downloads/population_by_age_group.csv")
df.head()
# Out:
#           Country     Total      65+  25-64 years  15-24 years  5-14 years  \
# 0     Afghanistan  40099460   964016     12995277      8727160    10922454
# 1         Albania   2854710   463442      1527360       399113      323402
# 2         Algeria  44177964  2731079     21871300      6007614     8697129
# 3  American Samoa     45056     3088        22433         7141        8365
# 4         Andorra     79057    11499        48651         8570        7797
#
#    0-4 years
# 0    6490554
# 1     141393
# 2    4870841
# 3       4029
# 4       2540

# %%
df['Country'].nunique()
# Out:
# 235

# %% [markdown]
# The dataset contains 252 countries. To keep the chart readable and focused, we visualized only the **top 10 countries by total population**.

# %%
top_10_df = df.sort_values(by= 'Total', ascending= False).head(10)

# %%
# Set figure size
plt.figure(figsize=(12, 6))

# Plot stacked bar
age_groups = ['65+', '25-64 years', '15-24 years', '5-14 years', '0-4 years']
top_10_df_plot = top_10_df.set_index('Country')[age_groups]

top_10_df_plot.plot(kind='bar', stacked=True, figsize=(14, 6), colormap='tab20c')
plt.title("Population by Age Group in Selected Countries")
plt.ylabel("Population")
plt.xlabel("Country")
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend(title="Age Group")
plt.show()

# %% [markdown]
# # Insights
#
# - The 25–64 years group forms the largest chunk of population in most countries.
# - Countries like Afghanistan have higher percentages in 0–14 years age group, indicating a younger population.
# - Aging trends are more visible in countries with larger 65+ groups.

# %%
plt.savefig("top10_age_distribution.png")
